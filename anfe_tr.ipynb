# %%
## Functions
import pandas as pd
import numpy as np

# Import functions from chaintools.py
from chaintools import dividechain
from chaintools import chainget
from chaintools import plot_points

# Function calculates bearing going from point A to point B (e.g., 120 degrees)
def bearing(A_x, A_y, B_x, B_y):
    X = B_x - A_x
    Y = B_y - A_y
    bearing = np.rad2deg(np.arctan2(X, Y))
    bearing = (bearing + 360) % 360
    return bearing

# Function converts a bearing (e.g., 45) to a direction (e.g., Northeast)
def bearing_to_direction_8(bearing):
    if isinstance(bearing, str):
        direction = 'A FATAL ERROR HAS OCCURED'
        print(direction)
    elif bearing >= 22.5 and bearing < 67.5:
        direction = 'Northeast'
    elif bearing >= 67.5 and bearing < 112.5:
        direction = 'East'
    elif bearing >= 112.5 and bearing < 157.5:
        direction = 'Southeast'
    elif bearing >= 157.5 and bearing < 202.5:
        direction = 'South'
    elif bearing >= 202.5 and bearing < 247.5:
        direction = 'Southwest'
    elif bearing >= 247.5 and bearing < 292.5:
        direction = 'West'
    elif bearing >= 292.5 and bearing < 337.5:
        direction = 'Northwest'
    elif bearing > 360 or bearing < 0:
        direction = 'A FATAL ERROR HAS OCCURED'
        print(direction)
    else:
        direction = 'North'
    return direction

def side_street_get(road, street_1, street_2):
    if road == street_1:
        side_street = street_2
    elif road == street_2:
        side_street = street_1
    else:
        print('A FATAL ERROR HAS OCCURED - Did you name your street_1 and street_2 properly?')
    return side_street

def i_am_the_law(length, side_street, distance_from_intersection,
                 direction_from_intersection, driving_direction, x_int, y_int):

    # Round to 0.5m and make clean (e.g., 20.5 metres or 20 metres not 20.0 metres)
    length = round(length*2)/2
    if length*2 % 2 == 0:
        length = int(length)

    distance_from_intersection = round(distance_from_intersection*2)/2
    if distance_from_intersection*2 % 2 == 0:
        distance_from_intersection = int(distance_from_intersection)

    # "an easterly" not "a easterly"
    n = ''
    if direction_from_intersection == 'East':
        n = 'n'
    
    # Round x and y
    x_int = round(x_int, 3)
    y_int = round(y_int, 3)

    if distance_from_intersection < 3:
        legal = (
        f'{driving_direction} side, commencing at its intersection with {side_street}'
        f'(Grid Coordinates X = {x_int}m, Y = {y_int}m and extending in a{n}'
        f'{direction_from_intersection.lower()}erly direction'
        f'following the {driving_direction.lower()}ern kerbline for {length} metres.'
        )
    else:
        legal = (
        f'{driving_direction} side, commencing {distance_from_intersection} metres'
        f'{direction_from_intersection.lower()} of its intersection with {side_street}'
        f'(Grid Coordinates X = {x_int}m, Y = {y_int}m and extending in a{n}'
        f'{direction_from_intersection.lower()}erly direction'
        f'following the {driving_direction.lower()}ern kerbline for {length} metres.'
        )
    return legal

def restriction_get(ruler_name, precision):
    import pandas as pd

    # Chainget (places intersections and items on ruler)
    ruler = pd.read_csv(ruler_name + '.csv')
    intersections = pd.read_csv('intersections.csv')
    items = pd.read_csv('items.csv')

    items = items[items['ruler']==ruler_name].reset_index()
    intersections = intersections[intersections['ruler']==ruler_name].reset_index()

    chain = dividechain(ruler, precision)
    items = chainget(chain, items)
    intersections = chainget(chain, intersections)

    from operator import index
    import numpy as np

    # Finds the distance from item to closest intersection (on same "direction")
    meta_list = [None] * len(items)
    distance_from_intersection = [None] * len(items)
    intersection_index = [None] * len(items)

    intersections_chain = intersections['Chainage']
    items_chain = items['Chainage']

    for i in range(len(items)):
        list = [999999] * len(intersections)
        for j in range(len(intersections)):
            list[j] = abs(items_chain[i] - intersections_chain[j])
        meta_list[i] = list
        distance_from_intersection[i] = min(list)
        intersection_index[i] = np.argmin(list)

    distances = pd.DataFrame(intersection_index, columns = ['intersection_index'])
    distances['distance_from_intersection'] = distance_from_intersection

    processed = pd.concat([items, distances], axis=1)

    # Both start and end of item were calculated
    # Code below drops duplicates keeping the shortest distance
    processed_2 = processed.sort_values('distance_from_intersection')\
                  .drop_duplicates('fid', keep='first')

    processed_3 = pd.merge(processed_2, intersections,
                           left_on='intersection_index', right_index =True,
                           how='left', suffixes = ('', '_intersection'))

    # Obtains bearing and direction from Intersection to Item
    processed_3['bearing_from_intersection'] = processed_3.apply(lambda x: bearing(
                                               x['x_intersection'], x['y_intersection'],
                                               x['x'], x['y']), axis=1)

    processed_3['direction_from_intersection'] = processed_3['bearing_from_intersection'].apply(bearing_to_direction_8)

    processed_3['side_street'] = processed_3.apply(lambda x: side_street_get(
                                                          x['road'], x['street_1'], x['street_2']), axis=1)

    ruler_to_directions = pd.read_csv(ruler_name + '_directions.csv')
    processed_4 = pd.merge(processed_3, ruler_to_directions, on='road', how='left')

    final = processed_4[['fid', 'old_new', 'restriction', 'length', 'road', 'driving_direction',
                         'fid_intersection', 'distance_from_intersection', 'direction_from_intersection',
                         'side_street', 'x_intersection', 'y_intersection']]

    final['legal'] = final.apply(lambda x: i_am_the_law(
                                        x['length'], x['side_street'], x['distance_from_intersection'],
                                        x['direction_from_intersection'], x['driving_direction'],
                                        x['x_intersection'], x['y_intersection']), axis=1)

    return final

# %%
bottomleft = restriction_get('Bottomleft', precision = 0.01)
topright = restriction_get('Topright', precision = 0.01)
combined = pd.concat([bottomleft, topright])
combined.to_csv('final.csv')
combined
# Out:
#     fid    old_new  restriction      length                road  \
# 0    88        New  No-stopping  133.562142    Ngaio Gorge Road
# 1     6  Extension  No-stopping  546.382236  Kaiwharawhara Road
# 2    77  Extension  No-stopping   25.812451        Crofton Road
# 3    76        Old  No-stopping   38.085531        Kenya Street
# 4    21  Extension  No-stopping   50.566971  Kaiwharawhara Road
# 5     3        New  No-stopping  431.808017    Ngaio Gorge Road
# 6    57        New     Bus stop   15.019999    Ngaio Gorge Road
# 7    11        New  No-stopping   12.993292    Ngaio Gorge Road
# 8    71        Old  No-stopping   33.912762        Kenya Street
# 9    86        New          P10    5.946617        Kenya Street
# 10   74        Old     Bus stop   10.838983  Kaiwharawhara Road
# 11   23  Extension  No-stopping  228.278945  Kaiwharawhara Road
# 12   85        Old  No-stopping    5.026048        Kenya Street
# 13   16        New  No-stopping   35.848280        Kenya Street
# 14   59        New     Bus stop   15.054743    Ngaio Gorge Road
# 15   65        Old     Bus stop   15.018579        Kenya Street
# 16    2        New  No-stopping  214.111295    Ngaio Gorge Road
# 17   69        Old  No-stopping   10.485889        Kenya Street
# 18   70        Old  No-stopping   34.811803        Kenya Street
# 19   75        Old     Bus stop   11.281661  Kaiwharawhara Road
# 20   62        Old  No-stopping  187.356005  Kaiwharawhara Road
# 21   58        New     Bus stop   13.061547    Ngaio Gorge Road
# 22   60        New     Bus stop   21.282839  Kaiwharawhara Road
# 0    14  Extension  No-stopping  178.325559        Kenya Street
# 1    17        New  No-stopping  114.843351        Crofton Road
# 2    78        Old  No-stopping   83.138284    Ngaio Gorge Road
# 3    89        Old  No-stopping   19.981373  Kaiwharawhara Road
# 4    83        New  No-stopping    5.982499  Kaiwharawhara Road
# 5    79        Old     Bus stop   13.457387        Crofton Road
# 6    40        New  No-stopping    8.584484  Kaiwharawhara Road
# 7    15        New  No-stopping  272.427237        Kenya Street
# 8    67        Old  No-stopping   12.915462  Kaiwharawhara Road
# 9    63        Old     Bus stop   11.008423  Kaiwharawhara Road
# 10   64        Old     Bus stop   14.391943        Kenya Street
# 11   73        Old  No-stopping   66.952561  Kaiwharawhara Road
# 12   87        Old     Bus Stop   12.220086  Kaiwharawhara Road
# 13   72        Old  No-stopping   26.226397  Kaiwharawhara Road
#
#    driving_direction  fid_intersection  distance_from_intersection  \
# 0               West                11                        0.00
# 1               West                11                        0.00
# 2              North                13                        0.38
# 3              North                13                        0.38
# 4               West                 1                        0.51
# 5               West                 6                        1.01
# 6               West                 7                       13.77
# 7               West                 7                       28.81
# 8              North                 9                       33.24
# 9              North                13                       38.46
# 10              West                 1                       50.03
# 11              West                 1                       60.86
# 12             North                13                       63.54
# 13             North                 9                      107.42
# 14              West                11                      134.42
# 15             North                 9                      143.72
# 16              West                11                      149.69
# 17             North                 9                      164.39
# 18             North                 9                      198.01
# 19              West                 1                      289.10
# 20              West                 1                      300.38
# 21              West                11                      363.76
# 22              West                 1                      488.50
# 0              South                10                        0.00
# 1              South                16                        0.00
# 2               East                10                        0.00
# 3               East                19                        0.10
# 4               East                18                        1.51
# 5              South                14                        5.64
# 6               East                18                       17.90
# 7              South                12                       27.48
# 8               East                17                       34.07
# 9               East                 2                       74.84
# 10             South                10                      178.65
# 11              East                 3                      237.78
# 12              East                 3                      304.69
# 13              East                 3                      316.90
#
#    direction_from_intersection          side_street  x_intersection  \
# 0                        North   Kaiwharawhara Road     1749066.529
# 1                        North     Ngaio Gorge Road     1749066.529
# 2                         West         Kenya Street     1748584.450
# 3                         West         Crofton Road     1748584.450
# 4                    Southwest            Hutt Road     1749912.060
# 5                         East  Trelissick Crescent     1748458.814
# 6                    Northwest  Trelissick Crescent     1748444.224
# 7                    Northwest  Trelissick Crescent     1748444.224
# 8                    Northeast  Trelissick Crescent     1748383.625
# 9                    Southwest         Crofton Road     1748584.450
# 10                   Northwest            Hutt Road     1749912.060
# 11                   Northwest            Hutt Road     1749912.060
# 12                   Southwest         Crofton Road     1748584.450
# 13                       North  Trelissick Crescent     1748383.625
# 14                   Northwest   Kaiwharawhara Road     1749066.529
# 15                       North  Trelissick Crescent     1748383.625
# 16                   Northwest   Kaiwharawhara Road     1749066.529
# 17                       North  Trelissick Crescent     1748383.625
# 18                       North  Trelissick Crescent     1748383.625
# 19                   Northwest            Hutt Road     1749912.060
# 20                   Northwest            Hutt Road     1749912.060
# 21                        West   Kaiwharawhara Road     1749066.529
# 22                   Northwest            Hutt Road     1749912.060
# 0                        North     Ngaio Gorge Road     1748394.214
# 1                    Southeast          Ottawa Road     1748563.806
# 2                        North         Kenya Street     1748394.214
# 3                    Northeast       Cameron Street     1749805.413
# 4                         East       Cameron Street     1749812.587
# 5                        South        Abbott Street     1748584.869
# 6                    Southeast       Cameron Street     1749812.587
# 7                    Southwest         Crofton Road     1748587.606
# 8                    Northwest            Hutt Road     1749928.894
# 9                    Southeast     Old Porirua Road     1749668.963
# 10                       North     Ngaio Gorge Road     1748394.214
# 11                        West     Old Porirua Road     1749650.973
# 12                        West     Old Porirua Road     1749650.973
# 13                        West     Old Porirua Road     1749650.973
#
#     y_intersection                                              legal
# 0      5431182.391  West side, commencing at its intersection with...
# 1      5431182.391  West side, commencing at its intersection with...
# 2      5431770.779  North side, commencing at its intersection wit...
# 3      5431770.779  North side, commencing at its intersection wit...
# 4      5430822.440  West side, commencing at its intersection with...
# 5      5431272.233  West side, commencing at its intersection with...
# 6      5431277.491  West side, commencing 14 metresnorthwest of it...
# 7      5431277.491  West side, commencing 29 metresnorthwest of it...
# 8      5431327.364  North side, commencing 33 metresnortheast of i...
# 9      5431770.779  North side, commencing 38.5 metressouthwest of...
# 10     5430822.440  West side, commencing 50 metresnorthwest of it...
# 11     5430822.440  West side, commencing 61 metresnorthwest of it...
# 12     5431770.779  North side, commencing 63.5 metressouthwest of...
# 13     5431327.364  North side, commencing 107.5 metresnorth of it...
# 14     5431182.391  West side, commencing 134.5 metresnorthwest of...
# 15     5431327.364  North side, commencing 143.5 metresnorth of it...
# 16     5431182.391  West side, commencing 149.5 metresnorthwest of...
# 17     5431327.364  North side, commencing 164.5 metresnorth of it...
# 18     5431327.364  North side, commencing 198 metresnorth of its ...
# 19     5430822.440  West side, commencing 289 metresnorthwest of i...
# 20     5430822.440  West side, commencing 300.5 metresnorthwest of...
# 21     5431182.391  West side, commencing 364 metreswest of its in...
# 22     5430822.440  West side, commencing 488.5 metresnorthwest of...
# 0      5431321.551  South side, commencing at its intersection wit...
# 1      5431918.344  South side, commencing at its intersection wit...
# 2      5431321.551  East side, commencing at its intersection with...
# 3      5430949.288  East side, commencing at its intersection with...
# 4      5430942.588  East side, commencing at its intersection with...
# 5      5431794.412  South side, commencing 5.5 metressouth of its ...
# 6      5430942.588  East side, commencing 18 metressoutheast of it...
# 7      5431757.751  South side, commencing 27.5 metressouthwest of...
# 8      5430829.092  East side, commencing 34 metresnorthwest of it...
# 9      5431079.406  East side, commencing 75 metressoutheast of it...
# 10     5431321.551  South side, commencing 178.5 metresnorth of it...
# 11     5431089.750  East side, commencing 238 metreswest of its in...
# 12     5431089.750  East side, commencing 304.5 metreswest of its ...
# 13     5431089.750  East side, commencing 317 metreswest of its in...
